# %% [markdown]
# <a href="https://colab.research.google.com/github/PandiRaja18/Machine-Learning/blob/ML/Basic_Img_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 70064, done.
# remote: Counting objects: 100% (70064/70064), done.
# remote: Compressing objects: 100% (70053/70053), done.
# remote: Total 72556 (delta 14), reused 70052 (delta 8), pack-reused 2492
# Receiving objects: 100% (72556/72556), 121.67 MiB | 21.00 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Checking out files: 100% (3002/3002), done.

# %%
# !pip uninstall opencv-python
# Out:
# Uninstalling opencv-python-4.1.2.30:
#   Would remove:
#     /usr/local/lib/python3.6/dist-packages/cv2/*
#     /usr/local/lib/python3.6/dist-packages/opencv_python-4.1.2.30.dist-info/*
# Proceed (y/n)? y
#   Successfully uninstalled opencv-python-4.1.2.30

# %%
# !pip install opencv-python==3.4.2.16
# Out:
# Collecting opencv-python==3.4.2.16
#   Downloading https://files.pythonhosted.org/packages/fa/7d/5042b668a8ed41d2a80b8c172f5efcd572e3c046c75ae029407e19b7fc68/opencv_python-3.4.2.16-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#      |████████████████████████████████| 25.0MB 62.6MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.16) (1.19.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.2.16

# %% [markdown]
# # **Load Display and Save the image**

# %%
import cv2
from google.colab.patches import cv2_imshow
 
# load the image and show some basic information on it
image = cv2.imread("machine_learning/OpenCv/images/bb.JPG")

# %%
# show the image
#image= cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x270 at 0x7FCE55B4AA20>

# %%
# save the image -- OpenCV handles converting file types automatically
cv2.imwrite("big_boss_1.jpg", image)
# Out:
# True

# %% [markdown]
# # **Drawing Functions**

# %%
import numpy as np

# %%
#Creatre a plain image of 500 - width and 500 - Height 
# 3 - color (RGB)
#datatype is unsigned integer 2^8=256
# *255 represents the canvas filled with white in  color.
canvas = np.ones((500, 500, 3), dtype="uint8")*255

# %%
black = (0, 0, 0)
cv2.line(canvas, (0, 0), (400, 400), black,3)
cv2_imshow(canvas)

# %%
red =[0,0,255] #BGR
# 5 is the thickness of the rectangle
cv2.rectangle(canvas, (150, 100), (100, 225), red, 5)
cv2_imshow(canvas)

# %%
green = (0, 255, 0)
cv2.rectangle(canvas, (300, 50), (425, 125), green, -1)
cv2_imshow(canvas)

# %%
canvas = np.zeros((500, 500, 3), dtype="uint8")

# %%
for i in range(0, 25):
	# randomly generate a radius size between 5 and 200, generate a random
	# color, and then pick a random point on our canvas where the circle
	# will be drawn
	radius = np.random.randint(5, high=300)
	color = np.random.randint(0, high=256, size = (3,)).tolist()
	pt = np.random.randint(0, high=400, size = (2,))

	# draw our random circle
	cv2.circle(canvas, tuple(pt), radius, color, -1)

# Show our masterpiece
cv2_imshow(canvas)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7FCE4D27DD68>

# %% [markdown]
# # **Write Text on image**

# %%
image = cv2.imread("machine_learning/OpenCv/images/big_boss.JPG")
#there are 8 font available in open cv2
cv2.putText(image, 'Big Boss 2', (30, 30), cv2.FONT_HERSHEY_SCRIPT_COMPLEX, 0.8, (0, 255, 0), 2)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x270 at 0x7FCE4D27D470>

# %% [markdown]
# # **Translate**

# %%
import imutils

# %%
image = cv2.imread("machine_learning/OpenCv/images/minion.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=960x600 at 0x7FCE4BA33048>

# %%
shifted = imutils.translate(image, 0, -180)
#(x,y) x-towards right for postive value , left for negative value and do nothing for '0'
#      y-Downwards for postive value , upwards for negative value and do nothing for '0'
cv2_imshow(shifted)
# Out:
# <PIL.Image.Image image mode=RGB size=960x600 at 0x7FCE4BA33198>

# %% [markdown]
# # **Rotate Image**

# %%
rotated = imutils.rotate(image, 180)
cv2_imshow(rotated)

# %% [markdown]
# # **Crop image**

# %%
crop = image[20:400,10:400]
cv2_imshow(crop)
# Out:
# <PIL.Image.Image image mode=RGB size=390x380 at 0x7FCE4BA3C780>

# %% [markdown]
# # **Resize without aspect Ratio**

# %%
resized = cv2.resize(image, (500,500))
cv2_imshow(resized)

# %% [markdown]
# # **Resize with aspect Ration**

# %%
resized = imutils.resize(image, width=500)
cv2_imshow(resized)

# %% [markdown]
# # **Flipping**

# %%
flipped = cv2.flip(image, 1)
cv2_imshow(flipped)

# %%
flipped = cv2.flip(image, 0)
cv2_imshow(flipped)

# %%
flipped = cv2.flip(image, -1)
cv2_imshow( flipped)

# %% [markdown]
# # **Bitwise Operation**

# %%
rectangle = np.zeros((300, 300), dtype = "uint8")
cv2.rectangle(rectangle, (25, 25), (275, 275), 255, -1)
cv2_imshow(rectangle)

# %%
circle = np.zeros((300, 300), dtype = "uint8")
cv2.circle(circle, (150, 150), 150, 255, -1)
cv2_imshow(circle)

# %%
bitwiseAnd = cv2.bitwise_and(rectangle, circle)
cv2_imshow(bitwiseAnd)

# %%
bitwiseOr = cv2.bitwise_or(rectangle, circle)
cv2_imshow(bitwiseOr)

# %%
bitwiseXor = cv2.bitwise_xor(rectangle, circle)
cv2_imshow(bitwiseXor)

# %%
bitwiseNot = cv2.bitwise_not(circle)
cv2_imshow(bitwiseNot)

# %% [markdown]
# # **Masking**

# %%
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.rectangle(mask, (452, 243), (690, 590), 255, -1)
cv2_imshow( mask)

# %%
masked = cv2.bitwise_and(image, image, mask=mask)
cv2_imshow(masked)

# %%
mask = np.zeros(image.shape[:2], dtype="uint8")
cv2.circle(mask, (585, 98), 50, 255, -1)
masked = cv2.bitwise_and(image, image, mask=mask)
cv2_imshow(mask)
cv2_imshow(masked)

# %% [markdown]
# # **Smoothing and Blurring**

# %% [markdown]
# **Average Blurr**

# %%
blurred = cv2.blur(image, (3, 3))
cv2_imshow(blurred)

# %% [markdown]
# **Gaussian Blur**

# %%
blurred = cv2.GaussianBlur(image, (3, 3), 0)
cv2_imshow(blurred)

# %% [markdown]
# **Median Blur**

# %%
blurred = cv2.medianBlur(image, 3)
cv2_imshow(blurred)

# %% [markdown]
# # **Thresholding**

# %%
image = cv2.imread("machine_learning/OpenCv/images/opencv_logo.png")
blurred = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image)

# %%
# check; if a pixel value is greater than our threshold (in this
# case, 200), we set it to be BLACK, otherwise it is WHITE.
(T, threshInv) = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY_INV)
cv2_imshow(threshInv)

# %%
(T, thresh) = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)
cv2_imshow(thresh)

# %%
cv2_imshow(cv2.bitwise_and(image, image, mask=threshInv))

# %% [markdown]
# **Otsu Thresholding**

# %%
(T, threshInv) = cv2.threshold(blurred, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
cv2_imshow(threshInv)

# %%
cv2_imshow(cv2.bitwise_and(image, image, mask=threshInv))

# %% [markdown]
# # **Contour**

# %%
image = cv2.imread("machine_learning/OpenCv/images/basic_shapes.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(image)

# %% [markdown]
# **Internal contour**

# %%
cnts = cv2.findContours(gray.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if imutils.is_cv2() else cnts[1]
clone = image.copy()
cv2.drawContours(clone, cnts, -1, (0, 255, 0), 2)

# %%
cv2_imshow(clone)

# %% [markdown]
# **External Contour**

# %%
cnts = cv2.findContours(gray.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if imutils.is_cv2() else cnts[1]
cv2.drawContours(clone, cnts, -1, (0, 255, 0), 2)

# %%
for c in cnts:
	# construct a mask by drawing only the current contour
	mask = np.zeros(gray.shape, dtype="uint8")
	cv2.drawContours(mask, [c], -1, 255, -1)

	# show the images
	#cv2.imshow("Image", image)
	#cv2.imshow("Mask", mask)
	cv2_imshow(cv2.bitwise_and(image, image, mask=mask))

# %% [markdown]
# # **License Plate Detection**

# %%
image = cv2.imread("machine_learning/OpenCv/images/1.jpg")
image = imutils.resize(image, width=500)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(image)

# %%
(T, threshInv) = cv2.threshold(gray, 0, 255,cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
cv2_imshow(threshInv)

# %%
cnts = cv2.findContours(threshInv.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if imutils.is_cv2() else cnts[1]
clone = image.copy()

for cnt in cnts:
	x,y,w,h = cv2.boundingRect(cnt)
	
	if (w<120 and w>90 and h<70 and h>30):
		print (x,y,w,h)
		cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
		cv2_imshow(image)
