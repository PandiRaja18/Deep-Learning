# %% [markdown]
# <a href="https://colab.research.google.com/github/PandiRaja18/Machine-Learning/blob/ML/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Face Detection  - Viola-Jones Method**

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1YSiue_HkgabePWSJSk_dfXkc_htbFx68)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1UzzB3lBsy9ewAv1u03iuAwnnqjdTZE5L)

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1xcz5AM58oplvDsMa4Mx6Oc97THLY5_bx)

# %% [markdown]
# **Final Step - AdaBoost and Cascading**

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 70064, done.
# remote: Counting objects: 100% (70064/70064), done.
# remote: Compressing objects: 100% (70053/70053), done.
# remote: Total 72556 (delta 14), reused 70052 (delta 8), pack-reused 2492
# Receiving objects: 100% (72556/72556), 121.67 MiB | 4.67 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Checking out files: 100% (3002/3002), done.

# %%
# !pip uninstall -y opencv-python
# Out:
# Uninstalling opencv-python-4.1.2.30:
#   Successfully uninstalled opencv-python-4.1.2.30

# %%
# !pip install opencv-python==3.4.2.16
# Out:
# Collecting opencv-python==3.4.2.16
#   Downloading https://files.pythonhosted.org/packages/fa/7d/5042b668a8ed41d2a80b8c172f5efcd572e3c046c75ae029407e19b7fc68/opencv_python-3.4.2.16-cp36-cp36m-manylinux1_x86_64.whl (25.0MB)
#      |████████████████████████████████| 25.0MB 1.5MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==3.4.2.16) (1.19.4)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: opencv-python
# Successfully installed opencv-python-3.4.2.16

# %%
# import the necessary packages
from imutils import paths
import cv2
from google.colab.patches import cv2_imshow

# %%
# load the face detector
detector = cv2.CascadeClassifier("machine_learning/OpenCv/face_detection/cascades/haarcascade_frontalface_default.xml")

image_paths = "machine_learning/OpenCv/face_detection/images/"

# %%
# Loop on images for detecting face
for path in sorted(list(paths.list_images(image_paths))): #Listdown all the images in the path

	frame = cv2.imread(path)

	gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
	#resize the image to 30,30 though it is far strech
	faceRects = detector.detectMultiScale(gray, scaleFactor=1.05, minNeighbors=5, minSize=(30, 30), flags=cv2.CASCADE_SCALE_IMAGE)

	# loop over the faces and draw a rectangle around each
	for (x, y, w, h) in faceRects: #cut the image by using four points
		cv2.rectangle(frame, (x, y), (x + w, y + h), (255,0, 0), 3)
	
	no_of_face = len(faceRects)

	cv2.putText(frame, "Face Detected -  "+str(no_of_face), (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)	
	cv2_imshow(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F38A3720240>
# <PIL.Image.Image image mode=RGB size=800x800 at 0x7F38A37201D0>
# <PIL.Image.Image image mode=RGB size=535x314 at 0x7F38A3720240>
